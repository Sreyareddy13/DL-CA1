# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreyareddy13/DL-CA1/blob/main/CA2_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import balanced_accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import h5py
import joblib
# Load and prepare data
df = pd.read_csv('Group A Dataset.csv')
df['label'] = df['label'].str.replace('.', '')  # Clean labels

# Remove specified columns
df = df.drop(['fnlwgt', 'education'], axis=1)

# Separate features and target
X = df.drop('label', axis=1)
y = df['label'].map({'<=50K': 0, '>50K': 1})  # Binary encoding

# Identify categorical and numerical columns
cat_cols = ['workclass', 'marital_status', 'occupation',
            'relationship', 'race', 'sex', 'native_country']
num_cols = ['age', 'education_num', 'capital_gain',
            'capital_loss', 'hour_per_week']

# Create preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
    ])

# Preprocess data
X_processed = preprocessor.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y, test_size=0.2, random_state=42)

# Calculate maximum parameters (1000)
# Architecture designed to stay under 1000 parameters
n_features = X_train.shape[1]
hidden1_units = 8  # (n_features+1)*8 < 500
hidden2_units = 4  # (8+1)*4 = 36
output_units = 1   # (4+1)*1 = 5
total_params = (n_features+1)*hidden1_units + (hidden1_units+1)*hidden2_units + (hidden2_units+1)*output_units
print(f"Total trainable parameters: {total_params} (must be <= 1000)")

# Build neural network with L2 regularization
model = Sequential([
    Dense(hidden1_units, activation='relu',
          input_shape=(n_features,),
          kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(hidden2_units, activation='relu',
          kernel_regularizer=l2(0.001)),
    Dropout(0.2),
    Dense(output_units, activation='sigmoid')
])

# Compile with AdamW optimizer
optimizer = AdamW(learning_rate=0.001, weight_decay=0.001)
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train with early stopping
history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=128,
                    validation_split=0.2,
                    verbose=1)

model.save('income_classifier_model.h5')

# Save preprocessor
import joblib
joblib.dump(preprocessor, 'preprocessor.pkl')

# Test script would look like this:
def load_and_test(model_path, test_data_path):
    # Load model
    model = tf.keras.models.load_model(model_path)

    # Load and preprocess test data (same preprocessing as training)
    df_test = pd.read_csv(test_data_path)
    df_test['label'] = df_test['label'].str.replace('.', '')
    X_test = df_test.drop(['label', 'fnlwgt', 'education'], axis=1)
    y_test = df_test['label'].map({'<=50K': 0, '>50K': 1})

    # Preprocess
    X_test_processed = preprocessor.transform(X_test)

    # Predict and calculate balanced accuracy
    y_pred = (model.predict(X_test) > 0.5).astype(int)
    print(f"Balanced Accuracy: {balanced_accuracy_score(y_test, y_pred):.4f}")
# Example usage:
# bal_acc = load_and_test('income_predictor.h5', 'test_data.csv')
# Out:
# Total trainable parameters: 769 (must be <= 1000)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7159 - loss: 0.6310 - val_accuracy: 0.8288 - val_loss: 0.4304
# Epoch 2/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8032 - loss: 0.4581 - val_accuracy: 0.8501 - val_loss: 0.3627
# Epoch 3/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8248 - loss: 0.4115 - val_accuracy: 0.8552 - val_loss: 0.3488
# Epoch 4/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8344 - loss: 0.3884 - val_accuracy: 0.8570 - val_loss: 0.3429
# Epoch 5/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8306 - loss: 0.3905 - val_accuracy: 0.8577 - val_loss: 0.3393
# Epoch 6/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8333 - loss: 0.3797 - val_accuracy: 0.8567 - val_loss: 0.3369
# Epoch 7/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8404 - loss: 0.3650 - val_accuracy: 0.8547 - val_loss: 0.3356
# Epoch 8/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8390 - loss: 0.3661 - val_accuracy: 0.8588 - val_loss: 0.3359
# Epoch 9/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8428 - loss: 0.3641 - val_accuracy: 0.8575 - val_loss: 0.3343
# Epoch 10/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8407 - loss: 0.3642 - val_accuracy: 0.8570 - val_loss: 0.3337
# Epoch 11/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8384 - loss: 0.3636 - val_accuracy: 0.8554 - val_loss: 0.3345
# Epoch 12/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8412 - loss: 0.3637 - val_accuracy: 0.8554 - val_loss: 0.3342
# Epoch 13/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8430 - loss: 0.3575 - val_accuracy: 0.8549 - val_loss: 0.3348
# Epoch 14/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8469 - loss: 0.3573 - val_accuracy: 0.8570 - val_loss: 0.3332
# Epoch 15/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8480 - loss: 0.3554 - val_accuracy: 0.8529 - val_loss: 0.3340
# Epoch 16/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8411 - loss: 0.3566 - val_accuracy: 0.8552 - val_loss: 0.3332
# Epoch 17/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8463 - loss: 0.3554 - val_accuracy: 0.8557 - val_loss: 0.3335
# Epoch 18/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8378 - loss: 0.3607 - val_accuracy: 0.8549 - val_loss: 0.3332
# Epoch 19/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8482 - loss: 0.3509 - val_accuracy: 0.8552 - val_loss: 0.3327
# Epoch 20/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8411 - loss: 0.3611 - val_accuracy: 0.8582 - val_loss: 0.3331
# Epoch 21/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8375 - loss: 0.3607 - val_accuracy: 0.8557 - val_loss: 0.3327
# Epoch 22/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8418 - loss: 0.3634 - val_accuracy: 0.8572 - val_loss: 0.3318
# Epoch 23/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8429 - loss: 0.3553 - val_accuracy: 0.8554 - val_loss: 0.3319
# Epoch 24/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8445 - loss: 0.3577 - val_accuracy: 0.8544 - val_loss: 0.3315
# Epoch 25/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8437 - loss: 0.3543 - val_accuracy: 0.8547 - val_loss: 0.3316
# Epoch 26/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8414 - loss: 0.3609 - val_accuracy: 0.8559 - val_loss: 0.3318
# Epoch 27/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8475 - loss: 0.3455 - val_accuracy: 0.8559 - val_loss: 0.3317
# Epoch 28/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8394 - loss: 0.3578 - val_accuracy: 0.8562 - val_loss: 0.3317
# Epoch 29/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8491 - loss: 0.3453 - val_accuracy: 0.8562 - val_loss: 0.3311
# Epoch 30/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8380 - loss: 0.3524 - val_accuracy: 0.8559 - val_loss: 0.3319
# Epoch 31/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8364 - loss: 0.3566 - val_accuracy: 0.8580 - val_loss: 0.3313
# Epoch 32/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8454 - loss: 0.3441 - val_accuracy: 0.8572 - val_loss: 0.3316
# Epoch 33/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8465 - loss: 0.3473 - val_accuracy: 0.8549 - val_loss: 0.3317
# Epoch 34/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8423 - loss: 0.3559 - val_accuracy: 0.8588 - val_loss: 0.3315
# Epoch 35/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8458 - loss: 0.3509 - val_accuracy: 0.8544 - val_loss: 0.3312
# Epoch 36/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8429 - loss: 0.3451 - val_accuracy: 0.8557 - val_loss: 0.3309
# Epoch 37/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8461 - loss: 0.3513 - val_accuracy: 0.8559 - val_loss: 0.3306
# Epoch 38/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8493 - loss: 0.3445 - val_accuracy: 0.8547 - val_loss: 0.3308
# Epoch 39/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8489 - loss: 0.3452 - val_accuracy: 0.8559 - val_loss: 0.3308
# Epoch 40/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8476 - loss: 0.3463 - val_accuracy: 0.8562 - val_loss: 0.3311
# Epoch 41/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8459 - loss: 0.3545 - val_accuracy: 0.8575 - val_loss: 0.3307
# Epoch 42/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8368 - loss: 0.3613 - val_accuracy: 0.8554 - val_loss: 0.3302
# Epoch 43/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8442 - loss: 0.3502 - val_accuracy: 0.8549 - val_loss: 0.3303
# Epoch 44/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8414 - loss: 0.3476 - val_accuracy: 0.8557 - val_loss: 0.3307
# Epoch 45/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8402 - loss: 0.3526 - val_accuracy: 0.8577 - val_loss: 0.3306
# Epoch 46/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8449 - loss: 0.3412 - val_accuracy: 0.8557 - val_loss: 0.3300
# Epoch 47/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8401 - loss: 0.3523 - val_accuracy: 0.8549 - val_loss: 0.3304
# Epoch 48/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8384 - loss: 0.3483 - val_accuracy: 0.8590 - val_loss: 0.3305
# Epoch 49/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8467 - loss: 0.3451 - val_accuracy: 0.8541 - val_loss: 0.3308
# Epoch 50/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8420 - loss: 0.3511 - val_accuracy: 0.8593 - val_loss: 0.3307
# Epoch 51/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8452 - loss: 0.3430 - val_accuracy: 0.8557 - val_loss: 0.3300
# Epoch 52/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8442 - loss: 0.3505 - val_accuracy: 0.8567 - val_loss: 0.3299
# Epoch 53/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8445 - loss: 0.3519 - val_accuracy: 0.8588 - val_loss: 0.3312
# Epoch 54/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8368 - loss: 0.3529 - val_accuracy: 0.8562 - val_loss: 0.3308
# Epoch 55/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8368 - loss: 0.3546 - val_accuracy: 0.8554 - val_loss: 0.3320
# Epoch 56/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8431 - loss: 0.3472 - val_accuracy: 0.8570 - val_loss: 0.3317
# Epoch 57/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8407 - loss: 0.3530 - val_accuracy: 0.8572 - val_loss: 0.3305
# Epoch 58/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8434 - loss: 0.3513 - val_accuracy: 0.8585 - val_loss: 0.3311
# Epoch 59/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8450 - loss: 0.3485 - val_accuracy: 0.8585 - val_loss: 0.3301
# Epoch 60/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8478 - loss: 0.3400 - val_accuracy: 0.8588 - val_loss: 0.3308
# Epoch 61/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8440 - loss: 0.3447 - val_accuracy: 0.8570 - val_loss: 0.3309
# Epoch 62/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8394 - loss: 0.3540 - val_accuracy: 0.8580 - val_loss: 0.3300
# Epoch 63/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8425 - loss: 0.3503 - val_accuracy: 0.8549 - val_loss: 0.3310
# Epoch 64/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8420 - loss: 0.3463 - val_accuracy: 0.8552 - val_loss: 0.3308
# Epoch 65/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8492 - loss: 0.3455 - val_accuracy: 0.8559 - val_loss: 0.3310
# Epoch 66/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8411 - loss: 0.3501 - val_accuracy: 0.8559 - val_loss: 0.3304
# Epoch 67/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8423 - loss: 0.3448 - val_accuracy: 0.8575 - val_loss: 0.3308
# Epoch 68/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8386 - loss: 0.3524 - val_accuracy: 0.8580 - val_loss: 0.3304
# Epoch 69/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8389 - loss: 0.3482 - val_accuracy: 0.8575 - val_loss: 0.3302
# Epoch 70/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8413 - loss: 0.3506 - val_accuracy: 0.8588 - val_loss: 0.3298
# Epoch 71/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8440 - loss: 0.3445 - val_accuracy: 0.8580 - val_loss: 0.3302
# Epoch 72/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8455 - loss: 0.3414 - val_accuracy: 0.8580 - val_loss: 0.3296
# Epoch 73/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8427 - loss: 0.3474 - val_accuracy: 0.8575 - val_loss: 0.3293
# Epoch 74/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8417 - loss: 0.3524 - val_accuracy: 0.8582 - val_loss: 0.3297
# Epoch 75/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8386 - loss: 0.3562 - val_accuracy: 0.8605 - val_loss: 0.3297
# Epoch 76/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8433 - loss: 0.3473 - val_accuracy: 0.8562 - val_loss: 0.3303
# Epoch 77/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8441 - loss: 0.3546 - val_accuracy: 0.8562 - val_loss: 0.3305
# Epoch 78/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8514 - loss: 0.3387 - val_accuracy: 0.8536 - val_loss: 0.3305
# Epoch 79/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8381 - loss: 0.3484 - val_accuracy: 0.8554 - val_loss: 0.3294
# Epoch 80/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8416 - loss: 0.3457 - val_accuracy: 0.8575 - val_loss: 0.3293
# Epoch 81/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8465 - loss: 0.3491 - val_accuracy: 0.8577 - val_loss: 0.3296
# Epoch 82/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8453 - loss: 0.3466 - val_accuracy: 0.8580 - val_loss: 0.3293
# Epoch 83/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8397 - loss: 0.3540 - val_accuracy: 0.8564 - val_loss: 0.3286
# Epoch 84/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8458 - loss: 0.3448 - val_accuracy: 0.8559 - val_loss: 0.3299
# Epoch 85/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8394 - loss: 0.3523 - val_accuracy: 0.8562 - val_loss: 0.3299
# Epoch 86/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8464 - loss: 0.3431 - val_accuracy: 0.8580 - val_loss: 0.3296
# Epoch 87/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8460 - loss: 0.3376 - val_accuracy: 0.8562 - val_loss: 0.3298
# Epoch 88/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8463 - loss: 0.3413 - val_accuracy: 0.8562 - val_loss: 0.3301
# Epoch 89/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8443 - loss: 0.3410 - val_accuracy: 0.8549 - val_loss: 0.3299
# Epoch 90/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8432 - loss: 0.3459 - val_accuracy: 0.8580 - val_loss: 0.3302
# Epoch 91/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8447 - loss: 0.3486 - val_accuracy: 0.8557 - val_loss: 0.3300
# Epoch 92/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8457 - loss: 0.3469 - val_accuracy: 0.8580 - val_loss: 0.3299
# Epoch 93/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8456 - loss: 0.3442 - val_accuracy: 0.8570 - val_loss: 0.3294
# Epoch 94/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8471 - loss: 0.3430 - val_accuracy: 0.8552 - val_loss: 0.3295
# Epoch 95/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8449 - loss: 0.3409 - val_accuracy: 0.8575 - val_loss: 0.3310
# Epoch 96/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8406 - loss: 0.3482 - val_accuracy: 0.8557 - val_loss: 0.3298
# Epoch 97/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8359 - loss: 0.3470 - val_accuracy: 0.8564 - val_loss: 0.3297
# Epoch 98/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8421 - loss: 0.3454 - val_accuracy: 0.8564 - val_loss: 0.3300
# Epoch 99/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8446 - loss: 0.3463 - val_accuracy: 0.8567 - val_loss: 0.3296
# Epoch 100/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8444 - loss: 0.3429 - val_accuracy: 0.8559 - val_loss: 0.3304
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
y_pred = (model.predict(X_test) > 0.5).astype(int)
print(f"Balanced Accuracy: {balanced_accuracy_score(y_test, y_pred):.4f}")
# Out:
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Balanced Accuracy: 0.7669
